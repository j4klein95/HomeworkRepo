# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
city_df = pd.read_csv('./raw_data/city_data.csv')
ride_df = pd.read_csv('./raw_data/ride_data.csv')

city_ride_df = pd.merge(city_df, ride_df, on='city', how='left')
city_ride_df

#ave_fare_list = [ave_fare_var]
#num_ride_list = [num_ride_var]
#num_drive_list = []


fare_df = city_ride_df.groupby('city')

ave_fare_var = fare_df['fare'].mean()

num_ride_var = fare_df['city'].count()
num_ride_var

type_var = fare_df['type']

num_drive = fare_df['driver_count']
num_drive.max()

full_df = pd.DataFrame(
{
    "Average Fare ($)": ave_fare_var,
    "Total Number of Rides per City": num_ride_var,
    "Driver Count": num_drive.max(),
    "Type": type_var.max()
}
)
full_df
# Out:
#                       Average Fare ($)  Driver Count  \
# city
# Alvarezhaven                 23.928710            21
# Alyssaberg                   20.609615            67
# Anitamouth                   37.315556            16
# Antoniomouth                 23.625000            21
# Aprilchester                 21.981579            49
# Arnoldview                   25.106452            41
# Campbellport                 33.711333            26
# Carrollbury                  36.606000             4
# Carrollfort                  25.395517            55
# Clarkstad                    31.051667            21
# Conwaymouth                  34.591818            18
# Davidtown                    22.978095            73
# Davistown                    21.497200            25
# East Cherylfurt              31.416154             9
# East Douglas                 26.169091            12
# East Erin                    24.478214            43
# East Jenniferchester         32.599474            22
# East Leslie                  33.660909             9
# East Stephen                 39.053000             6
# East Troybury                33.244286             3
# Edwardsbury                  26.876667            11
# Erikport                     30.043750             3
# Eriktown                     25.478947            15
# Floresberg                   32.310000             7
# Fosterside                   23.034583            69
# Hernandezshire               32.002222            10
# Horneland                    21.482500             8
# Jacksonfort                  32.006667             6
# Jacobfort                    24.779355            52
# Jasonfort                    27.831667            25
# ...                                ...           ...
# South Roy                    26.031364            35
# South Shannonborough         26.516667             9
# Spencertown                  23.681154            68
# Stevensport                  31.948000             6
# Stewartview                  21.614000            49
# Swansonbury                  27.464706            64
# Thomastown                   30.308333             1
# Tiffanyton                   28.510000            21
# Torresshire                  24.207308            70
# Travisville                  27.220870            37
# Vickimouth                   21.474667            13
# Webstertown                  29.721250            26
# West Alexis                  19.523000            47
# West Brandy                  24.157667            12
# West Brittanyton             25.436250             9
# West Dawnfurt                22.330345            34
# West Evan                    27.013333             4
# West Jefferyfurt             21.072857            65
# West Kevintown               21.528571             5
# West Oscar                   24.280000            11
# West Pamelaborough           33.799286            27
# West Paulport                33.278235             5
# West Peter                   24.875484            61
# West Sydneyhaven             22.368333            70
# West Tony                    29.609474            17
# Williamchester               34.278182            26
# Williamshire                 26.990323            70
# Wiseborough                  22.676842            55
# Yolandafurt                  27.205500             7
# Zimmermanmouth               28.301667            45
#
#                       Total Number of Rides per City      Type
# city
# Alvarezhaven                                      31     Urban
# Alyssaberg                                        26     Urban
# Anitamouth                                         9  Suburban
# Antoniomouth                                      22     Urban
# Aprilchester                                      19     Urban
# Arnoldview                                        31     Urban
# Campbellport                                      15  Suburban
# Carrollbury                                       10  Suburban
# Carrollfort                                       29     Urban
# Clarkstad                                         12  Suburban
# Conwaymouth                                       11  Suburban
# Davidtown                                         21     Urban
# Davistown                                         25     Urban
# East Cherylfurt                                   13  Suburban
# East Douglas                                      22     Urban
# East Erin                                         28     Urban
# East Jenniferchester                              19  Suburban
# East Leslie                                       11     Rural
# East Stephen                                      10     Rural
# East Troybury                                      7     Rural
# Edwardsbury                                       27     Urban
# Erikport                                           8     Rural
# Eriktown                                          19     Urban
# Floresberg                                        10  Suburban
# Fosterside                                        24     Urban
# Hernandezshire                                     9     Rural
# Horneland                                          4     Rural
# Jacksonfort                                        6     Rural
# Jacobfort                                         31     Urban
# Jasonfort                                         12  Suburban
# ...                                              ...       ...
# South Roy                                         22     Urban
# South Shannonborough                              15  Suburban
# Spencertown                                       26     Urban
# Stevensport                                        5     Rural
# Stewartview                                       30     Urban
# Swansonbury                                       34     Urban
# Thomastown                                        24  Suburban
# Tiffanyton                                        13  Suburban
# Torresshire                                       26     Urban
# Travisville                                       23     Urban
# Vickimouth                                        15     Urban
# Webstertown                                       16  Suburban
# West Alexis                                       20     Urban
# West Brandy                                       30     Urban
# West Brittanyton                                  24     Urban
# West Dawnfurt                                     29     Urban
# West Evan                                         12  Suburban
# West Jefferyfurt                                  21     Urban
# West Kevintown                                     7     Rural
# West Oscar                                        29     Urban
# West Pamelaborough                                14  Suburban
# West Paulport                                     17  Suburban
# West Peter                                        31     Urban
# West Sydneyhaven                                  18     Urban
# West Tony                                         19  Suburban
# Williamchester                                    11  Suburban
# Williamshire                                      31     Urban
# Wiseborough                                       19     Urban
# Yolandafurt                                       20     Urban
# Zimmermanmouth                                    24     Urban
#
# [125 rows x 4 columns]

# %%
#Gold, Light Sky Blue, and Light Coral
handles = ['Urban', 'Suburban', 'Rural']
plt.scatter(
    full_df['Total Number of Rides per City'][full_df["Type"] == 'Urban'], 
    full_df['Average Fare ($)'][full_df["Type"] == 'Urban'],
    s=full_df['Driver Count']*15,
    marker='o', 
    c='gold',
    edgecolors='black',
    alpha=0.65,
    linewidth=1
)
plt.scatter(
    full_df['Total Number of Rides per City'][full_df["Type"] == 'Suburban'], 
    full_df['Average Fare ($)'][full_df["Type"] == 'Suburban'],
    s=full_df['Driver Count']*15,
    marker='o', 
    c='lightskyblue',
    edgecolors='black',
    alpha=0.65,
    linewidth=1
)
plt.scatter(
    full_df['Total Number of Rides per City'][full_df["Type"] == 'Rural'], 
    full_df['Average Fare ($)'][full_df["Type"] == 'Rural'],
    s=full_df['Driver Count']*15,
    marker='o', 
    c='lightcoral',
    edgecolors='black',
    alpha=0.65,
    linewidth=1
)

plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare($)')
plt.title('Pyber Ride Sharing Data (2016)')
plt.legend(handles, loc="upper right")

# %%
plt.show()

# %%
colors = ['gold', 'lightskyblue', 'lightcoral']
types = ['Urban', 'Suburban', 'Rural']
type_df = city_ride_df.groupby('type')
summm = type_df['fare'].sum()
type_df.max()
summm
type_df.max()
# Out:
#                     city  driver_count                 date   fare  \
# type
# Rural     West Kevintown            10  2016-11-28 09:09:15  59.65
# Suburban  Williamchester            27  2016-12-04 15:42:42  49.95
# Urban     Zimmermanmouth            73  2016-12-05 01:52:05  44.99
#
#                 ride_id
# type
# Rural     9985496304508
# Suburban  9976923455740
# Urban     9997901376574

# %%
plt.pie(
    type_df['fare'].sum(),
    labels=types,
    shadow=True,
    colors=colors,
    explode=(0,.01,.1),
    autopct='%1.1f%%',
    startangle=140
)

plt.axis('equal')
plt.tight_layout()
plt.title('% Of Total Fares By City Type')

plt.show()

# %%
plt.pie(
    type_df['city'].count(),
    labels=types,
    shadow=True,
    colors=colors,
    explode=(0,.01,.1),
    autopct='%1.1f%%',
    startangle=140
)

plt.axis('equal')
plt.tight_layout()
plt.title('% Of Total Rides By City Type')

plt.show()

# %%
plt.pie(
    type_df['driver_count'].sum(),
    labels=types,
    shadow=True,
    colors=colors,
    explode=(0,.01,.1),
    autopct='%1.1f%%',
    startangle=140
)

plt.axis('equal')
plt.tight_layout()
plt.title('% Of Total Drivers By City Type')

plt.show()
